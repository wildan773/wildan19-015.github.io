# %% [markdown]
# # Crawler

# %% [markdown]
# Web crawler atau yang juga dikenal web spider, spider bot, web bot, crawler, adalah sebuah program software komputer yang digunakan oleh mesin pencari untuk mengindeks halaman web dan konten yang dimiliki setiap website.

# %% [markdown]
# ## Proses Crawler Website Portal Akademik UTM

# %% [markdown]
# Menggunakan library scrapy untuk proses menggambil data abstrak di website PTA.
# Menggunakan library json untuk mengambil File json
# Menyimpan kedalam file .csv

# %% [markdown]
#     import scrapy
#     import json
#
#     class Pta(scrapy.Spider):
#         name = "pta"
#         file_json = open("url.json")
#         start_urls = json.loads(file_json.read())
#         urls = []
#
#         for i in range(len(start_urls)):
#             b = start_urls[i]['url'][0]
#             urls.append(b)
#
#         def start_requests(self):
#             for url in self.urls:
#                 yield scrapy.Request(url = url, callback = self.parse)
#
#         def parse(self, response):
#
#
#             for jurnal in response.css('#content_journal > ul > li'):
#                 yield {
#                     'Judul':data_abstrak.css('div:nth-child(2) > a::text').get(),
#                     'Penulis':data_abstrak.css('div:nth-child(2) > div:nth-child(2) > span::text').get()[10:],
#                     'Dosbing_1':data_abstrak.css('div:nth-child(2) > div:nth-child(3) > span::text').get()[21:],
#                     'Dosbing_2':data_abstrak.css('div:nth-child(2) > div:nth-child(4) > span::text').get()[22:],
#                     'Abstrak_indo':data_abstrak.css('div:nth-child(4) > div:nth-child(2) > p::text').get(),
#                 }

# %% [markdown]
#  Url di bawah disimpan di file json

# %%
[
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/060411100755"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080411100102"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/050411100662"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080411100014"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080411100041"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080411100012"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100170"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/050411100558"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100133"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080411100010"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080411100086"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080411100052"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/060411100818"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080411100125"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080411100029"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100007"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100126"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100109"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080411100083"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100092"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/040411100468"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/040411100476"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/040411100480"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100070"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080411100115"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100124"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100072"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100152"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100114"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100036"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100083"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100102"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/050411100538"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080411100011"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100158"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080411100002"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080411100062"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100155"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/050411100614"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/050411100566"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/050411100651"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100119"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080411100113"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100136"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100023"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100120"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100143"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100037"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100079"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100050"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100029"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/060411100824"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/060411100772"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080411100001"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/060411100801"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080411100078"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100081"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100042"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070411100129"]},
{"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080411100003"]}
]

# %% [markdown]
# ## Hasil Crawler

# %%
import pandas as pd

df = pd.read_csv('data\data_abstrak.csv')
df.head(10)
# Out:
#                                                Judul  \
# 0  APLIKASI DAN DESAIN MODEL DECISION AID PELANGG...
# 1  ANALISA DATA ANTARAN POS EXPRESS MENGGUNAKAN\r...
# 2  Model Penjualan Produk Unggulan Batik Khas Pam...
# 3  PENERAPAN METODE ANALYTICAL HIERARCHY PROCESS ...
# 4  PENGELOMPOKAN KUALITAS KELAS PADA SISWA MENGGU...
# 5  SISTEM PENDUKUNG KEPUTUSAN PEMILIHAN KARYAWAN ...
# 6  Deteksi Manusia Menggunakan Histogram of Orien...
# 7  KLASIFIKASI STATUS GIZI BALITA MENGGUNAKAN KOH...
# 8  Aplikasi Penilaian Kinerja dengan Metodologi C...
# 9  APLIKASI CITRA MOSAIC PANORAMIC MENGGUNAKAN ME...
#
#                          Penulis                            Dosbing_1  \
# 0             Ardiyanto Setiawan  Moch. Kautsar Sophan, S.Kom., M.MT.
# 1          siti murtasiyah warda    Bain Khusnul Khotimah.,S.T.,M.Kom
# 2                  Murni Rotifah    Moch. Kautsar Sophan, S.Kom, M.MT
# 3                       Helyatin           Bain Khusnul K, S.T.,M.Kom
# ...
