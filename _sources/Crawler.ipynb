# %% [markdown]
# # Crawling Abstrak Website PTA ekonomi-manajemen

# %% [markdown]
# Web crawler atau yang juga dikenal web spider, spider bot, web bot, crawler, adalah sebuah program software komputer yang digunakan oleh mesin pencari untuk mengindeks halaman web dan konten yang dimiliki setiap website.

# %% [markdown]
# ## Proses Crawler Website Portal Akademik UTM

# %% [markdown]
# Crawler akan masuk ke target yang telah ditentukan yaitu web https://pta.trunojoyo.ac.id/c_search/byprod/7/

# %% [markdown]
#     #import library
#     import scrapy
#
#     class Url(scrapy.Spider):
#         name = "url"
#         start_urls = []
#
#         # menetukan target url
#         def __init__(self):
#             url = 'https://pta.trunojoyo.ac.id/c_search/byprod/7/'
#             for page in range(1,13):
#                 self.start_urls.append(url + str(page))
#
#         def parse(self, response):
#             for page in range(1,6):
#                 for url in response.css('#content_journal > ul'):
#                     yield {
#                         'url' : url.css('li:nth-child(1) > div:nth-child(3) > a ::attr(href)').extract()
#                     }

# %% [markdown]
# Menggunakan library scrapy untuk proses menggambil data abstrak di website PTA.
# Menggunakan library json untuk mengambil File json
# Menyimpan kedalam file .csv

# %% [markdown]
#     #Import Library
#     import scrapy
#     import json
#
#     #Mengambil url dari file json
#     class Pta(scrapy.Spider):
#         name = "pta"
#         file_json = open("url.json")
#         start_urls = json.loads(file_json.read())
#         urls = []
#
#         for i in range(len(start_urls)):
#             b = start_urls[i]['url'][0]
#             urls.append(b)
#
#         def start_requests(self):
#             for url in self.urls:
#                 yield scrapy.Request(url = url, callback = self.parse)
#
#         def parse(self, response):
#
#             #memasukkan tiap atribut yang akan diambil kedalam colom
#             for jurnal in response.css('#content_journal > ul > li'):
#                 yield {
#                     'Judul':data_abstrak.css('div:nth-child(2) > a::text').get(),
#                     'Penulis':data_abstrak.css('div:nth-child(2) > div:nth-child(2) > span::text').get()[10:],
#                     'Dosbing_1':data_abstrak.css('div:nth-child(2) > div:nth-child(3) > span::text').get()[21:],
#                     'Dosbing_2':data_abstrak.css('div:nth-child(2) > div:nth-child(4) > span::text').get()[22:],
#                     'Abstrak_indo':data_abstrak.css('div:nth-child(4) > div:nth-child(2) > p::text').get(),
#                 }

# %% [markdown]
#  Url yang akan kita ambil data abstaknya  disimpan di file json seperti dibawah.

# %% [markdown]
# [
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100070"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100070"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100070"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100070"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100013"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100013"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100013"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100013"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100013"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100070"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100025"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100025"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100025"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100025"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100025"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100008"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100008"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100008"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100008"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100008"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100119"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100119"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100119"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100119"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100119"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100104"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100104"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100104"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100104"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100104"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070211100045"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070211100045"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070211100045"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070211100045"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/070211100045"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100100"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100100"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100100"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100100"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/080211100100"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100090"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100090"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100090"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100090"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100090"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100052"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100052"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100052"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100052"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100052"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100065"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100065"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100065"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100065"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100065"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100056"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100056"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100056"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100056"]},
# {"url": ["https://pta.trunojoyo.ac.id/welcome/detail/090211100056"]}
# ]

# %% [markdown]
# ## Hasil Crawler

# %%
import pandas as pd

df = pd.read_csv('data\data.csv')
df.head(10)
# Out:
#                                                Judul  \
# 0  Analisis Inovasi Dan Keunggulan Bersaing \r\nD...
# 1  Pengaruh Bauran Pemasaran Terhadap Keputusan P...
# 2  ANALISIS PORTOFOLIO YANG OPTIMAL DI BEI DENGAN...
# 3  PENGARUH KOMPETENSI DOSEN TERHADAP KINERJA DOS...
# 4  PENGARUH FAKTOR-FAKTOR PELATIHAN DAN PENGEMBAN...
# 5  analisis faktor-faktor yang berpengaruh terhad...
# 6  Pengaruh Kompensasi Terhadap Kinerja Karywan p...
# 7  PENGARUH STRUKTUR MODAL DAN LIKUIDITAS TERHADA...
# 8  PENGARUH KUALITAS PELAYANAN TERHADAP KEPUASAN ...
# 9  PENGARUH PERILAKU KONSUMEN TERHADAP KEPUTUSAN ...
#
#                                     Mahasiswa  \
# 0                  Penulis : Sandy Ardiansyah
# 1                      Penulis : Mahrus Saleh
# 2                    Penulis : Mira Dwiastuti
# 3                        Penulis : Aththaariq
# 4                           Penulis : SATIYAH
# 5                           Penulis : Jailani
# 6                   Penulis : agustin pratiwi
# ...
